# %% [markdown]
# ## Máster en Big Data y Data Science
#
# ### Metodologías de gestión y diseño de proyectos de big data
#
# #### AP1 - Exploración de los datos
#
# ---
#
# En esta libreta se realiza un EDA -básico- de los datos del escenario.
#
# ---

# %% [markdown]
# ##### Importación de librerías

# %%
import pandas as pd
# from ydata_profiling import ProfileReport
import dtale as dt
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ----
#
# ##### Lectura de los datasets

# %%
df_creditos = pd.read_csv("../../data/raw/datos_creditos.csv", sep=";")
df_creditos.head(1)
# Out:
#     id_cliente  edad  importe_solicitado  duracion_credito  \
# 0  713061558.0    22               35000                 3
#
#    antiguedad_empleado situacion_vivienda  ingresos objetivo_credito  \
# 0                123.0           ALQUILER     59000         PERSONAL
#
#    pct_ingreso  tasa_interes  estado_credito falta_pago
# 0         0.59         16.02               1          Y

# %%
df_tarjetas = pd.read_csv("../../data/raw/datos_tarjetas.csv", sep=";")
df_tarjetas.head(1)
# Out:
#     id_cliente  antiguedad_cliente estado_civil estado_cliente  \
# 0  713061558.0                36.0       CASADO         ACTIVO
#
#    gastos_ult_12m genero  limite_credito_tc         nivel_educativo  \
# 0          1088.0      M             4010.0  UNIVERSITARIO_COMPLETO
#
#   nivel_tarjeta  operaciones_ult_12m  personas_a_cargo
# 0          Blue                 24.0               2.0

# %% [markdown]
# ----
#
# ##### Descripción de los datasets

# %%
def reporte_descripcion_dataset(df):
    columnas = df.columns
    print("Columnas del dataset:\n")
    for col in columnas:
        print(col)
    print(f"\nCantidad de filas: {df.shape[0]}")

# %%
print("Descripción del dataset 'datos_creditos'")
reporte_descripcion_dataset(df_creditos)
# Out:
# Descripción del dataset 'datos_creditos'
# Columnas del dataset:
#
# id_cliente
# edad
# importe_solicitado
# duracion_credito
# antiguedad_empleado
# situacion_vivienda
# ingresos
# objetivo_credito
# pct_ingreso
# tasa_interes
# estado_credito
# falta_pago
#
# Cantidad de filas: 10127

# %%
print("Descripción del dataset 'datos_tarjetas'")
reporte_descripcion_dataset(df_tarjetas)
# Out:
# Descripción del dataset 'datos_tarjetas'
# Columnas del dataset:
#
# id_cliente
# antiguedad_cliente
# estado_civil
# estado_cliente
# gastos_ult_12m
# genero
# limite_credito_tc
# nivel_educativo
# nivel_tarjeta
# operaciones_ult_12m
# personas_a_cargo
#
# Cantidad de filas: 10127

# %% [markdown]
# ----
#
# ##### Obtención de metadatos

# %%
# Se usa la librería dtale para poder obtener una vista interactiva de los datos

# Dataset: datos_creditos

creditos = dt.show(df_creditos)
creditos.open_browser()
# Out:
# 2023-11-03 11:33:57,958 - INFO     - Executing shutdown due to inactivity...
# 2023-11-03 11:34:06,192 - INFO     - Executing shutdown...
# 2023-11-03 11:34:06,192 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer

# %%
# Dataset: datos_tarjetas

tarjetas = dt.show(df_tarjetas)
tarjetas.open_browser()
# Out:
# 2023-10-27 09:32:56,728 - ERROR    - Exception occurred while processing request: could not convert string to float: 'ALQUILER'
# Traceback (most recent call last):
#   File "c:\Users\usuario\anaconda3\envs\VIU-13MBID\Lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\usuario\anaconda3\envs\VIU-13MBID\Lib\site-packages\dtale\views.py", line 3286, in get_corr_analysis
#     column_name, max_score, corrs, ranks = correlations.get_analysis(data_id)
#                                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\usuario\anaconda3\envs\VIU-13MBID\Lib\site-packages\dtale\correlations.py", line 80, in get_analysis
#     corr_matrix, _ = build_matrix(
#                      ^^^^^^^^^^^^^
#   File "c:\Users\usuario\anaconda3\envs\VIU-13MBID\Lib\site-packages\dtale\correlations.py", line 33, in build_matrix
#     data = data.corr(method="pearson")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\usuario\anaconda3\envs\VIU-13MBID\Lib\site-packages\pandas\core\frame.py", line 10054, in corr
#     mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\usuario\anaconda3\envs\VIU-13MBID\Lib\site-packages\pandas\core\frame.py", line 1838, in to_numpy
#     result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\usuario\anaconda3\envs\VIU-13MBID\Lib\site-packages\pandas\core\internals\managers.py", line 1732, in as_array
#     arr = self._interleave(dtype=dtype, na_value=na_value)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\usuario\anaconda3\envs\VIU-13MBID\Lib\site-packages\pandas\core\internals\managers.py", line 1794, in _interleave
#     result[rl.indexer] = arr
#     ~~~~~~^^^^^^^^^^^^
# ValueError: could not convert string to float: 'ALQUILER'

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go
df = df_creditos
if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['edad'])]['edad']

import scipy.stats as sts
import plotly.express as px

qq_x, qq_y = sts.probplot(s, dist="norm", fit=False)
chart = px.scatter(x=qq_x, y=qq_y, trendline='ols', trendline_color_override='red')
figure = go.Figure(data=chart, layout=go.Layout({
    'legend': {'orientation': 'h'}, 'title': {'text': 'edad QQ Plot'}
}))

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
chart.pop('id', None) # for some reason iplot does not like 'id'
iplot(chart)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="bcaaeb3a-b968-4784-b2ce-d9d1712e711d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcaaeb3a-b968-4784-b2ce-d9d1712e711d")) {                    Plotly.newPlot(                        "bcaaeb3a-b968-4784-b2ce-d9d1712e711d",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[-3.813727792057895,-3.5887493774018617,-3.465242886235325,-3.379099229654715,-3.312481543012095,-3.2579486749321003,-3.211662798393494,-3.1713778713845033,-3.1356629846736084,-3.103548958041789,-3.07434817426628,-3.0475546863085383,-3.022785122810265,-2.999741874475004,-2.9781891709322537,-2.957936977208143,-2.9388298257017946,-2.9207388701961383,-2.9035561053189407,-2.8871900786406597,-2.871562654775846,-2.8566065356849437,-2.8422633341891763,-2.8284820586401733,-2.8152179075534915,-2.8024313009638937,-2.790087094713232,-2.7781539376400564,-2.7666037415143236,-2.755411240743226,-2.7445536241640265,-2.73401022518056,-2.723762259467117,-2.7137926017195997,-2.7040855946652465,-2.69462688488246,-2.685403281028076,-2.676402630891699,-2.6676137143478584,-2.6590261497958023,-2.6506303120932064,-2.64241726032615,-2.6343786740305086,-2.6265067967025297,-2.618794385618931,-2.6112346671373468,-2.6038212967725696,-2.5965483234476388,-2.589410157405393,-2.5824015413386725,-2.5755175243584443,-2.568753438470736,-2.5621048772770196,-2.5555676766499156